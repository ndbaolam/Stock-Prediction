# %%
import pandas as pd

# %%
df = pd.read_parquet("../data/processed/D1/")
df
# Out:
#            open    high     low   close       volume ticket_name  \
# 0          0.12    0.14    0.12    0.14  170539824.0        AAPL
# 1          0.14    0.14    0.13    0.14  152723900.0        AAPL
# 2          0.14    0.17    0.13    0.16  433041952.0        AAPL
# 3          0.16    0.16    0.15    0.15  251914152.0        AAPL
# 4          0.15    0.16    0.15    0.16  188994988.0        AAPL
# ...         ...     ...     ...     ...          ...         ...
# 2795347  288.59  290.99  282.43  282.43     146485.0        ZBRA
# 2795348  282.60  282.60  282.59  282.59        667.0        ZBRA
# 2795349  282.30  283.54  279.19  280.28      90136.0        ZBRA
# 2795350  282.29  286.91  278.45  285.44      78432.0        ZBRA
# 2795351  283.96  286.16  282.33  284.50     152719.0        ZBRA
#
#          price_change  daily_return  log_return           VMA  vol_change  \
# 0                 NaN           NaN         NaN  1.705398e+08         NaN
# ...

# %%
df.dtypes
